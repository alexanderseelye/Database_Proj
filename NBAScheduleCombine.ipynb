# %%
import pandas as pd

# %%
df_oct = pd.read_excel("oct.xlsx")
df_nov = pd.read_excel("nov.xlsx")
df_dec = pd.read_excel("dec.xlsx")
df_jan = pd.read_excel("jan.xlsx")
df_feb = pd.read_excel("feb.xlsx")
df_march = pd.read_excel("march.xlsx")
df_april = pd.read_excel("april.xlsx")

# %%
print(df_oct.columns)
print(df_nov.columns)
# Out:
# Index(['Date', 'Start (ET)', 'Visitor/Neutral', 'PTS', 'Home/Neutral', 'PTS.1',
#        'Unnamed: 6', 'Unnamed: 7', 'Attend.', 'Arena', 'Notes'],
#       dtype='object')
# Index(['Date', 'Start (ET)', 'Visitor/Neutral', 'PTS', 'Home/Neutral', 'PTS.1',
#        'Unnamed: 6', 'Unnamed: 7', 'Attend.', 'Arena', 'Notes'],
#       dtype='object')

# %%
frames = [df_oct, df_nov, df_dec, df_jan, df_feb, df_march, df_april]
schedule = pd.concat(frames)

# %%
schedule.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                 Date Start (ET)         Visitor/Neutral    PTS  \
# 0  Tue, Oct 24, 2023      7:30p      Los Angeles Lakers  107.0
# 1  Tue, Oct 24, 2023     10:00p            Phoenix Suns  108.0
# 2  Wed, Oct 25, 2023      7:00p         Houston Rockets   86.0
# 3  Wed, Oct 25, 2023      7:00p          Boston Celtics  108.0
# 4  Wed, Oct 25, 2023      7:00p      Washington Wizards  120.0
# 5  Wed, Oct 25, 2023      7:00p           Atlanta Hawks  110.0
# 6  Wed, Oct 25, 2023      7:30p         Detroit Pistons  102.0
# 7  Wed, Oct 25, 2023      7:30p  Minnesota Timberwolves   94.0
# 8  Wed, Oct 25, 2023      7:30p     Cleveland Cavaliers  114.0
# ...

# %%
schedule.drop(columns=["Start (ET)", "Unnamed: 6", "Unnamed: 7", "Attend.", "Arena", "Notes"], inplace=True)
schedule.head(10)
# Out:
#                 Date         Visitor/Neutral    PTS           Home/Neutral  \
# 0  Tue, Oct 24, 2023      Los Angeles Lakers  107.0         Denver Nuggets
# 1  Tue, Oct 24, 2023            Phoenix Suns  108.0  Golden State Warriors
# 2  Wed, Oct 25, 2023         Houston Rockets   86.0          Orlando Magic
# 3  Wed, Oct 25, 2023          Boston Celtics  108.0        New York Knicks
# 4  Wed, Oct 25, 2023      Washington Wizards  120.0         Indiana Pacers
# 5  Wed, Oct 25, 2023           Atlanta Hawks  110.0      Charlotte Hornets
# 6  Wed, Oct 25, 2023         Detroit Pistons  102.0             Miami Heat
# 7  Wed, Oct 25, 2023  Minnesota Timberwolves   94.0        Toronto Raptors
# 8  Wed, Oct 25, 2023     Cleveland Cavaliers  114.0          Brooklyn Nets
# 9  Wed, Oct 25, 2023    New Orleans Pelicans  111.0      Memphis Grizzlies
#
#    PTS.1
# 0  119.0
# 1  104.0
# 2  116.0
# 3  104.0
# 4  143.0
# 5  116.0
# 6  103.0
# 7   97.0
# 8  113.0
# 9  104.0

# %%
schedule.to_excel("Schedule.xlsx")
print("Success")
# Out:
# Success
