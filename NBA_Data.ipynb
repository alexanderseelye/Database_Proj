# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-da3397eb-ff9b-429c-b409-8c264272e653" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da3397eb-ff9b-429c-b409-8c264272e653">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle datasets download -d sumitrodatta/nba-aba-baa-stats
# Out:
# ...
#  98% 10.0M/10.2M [00:01<00:00, 12.3MB/s]
# 100% 10.2M/10.2M [00:01<00:00, 7.14MB/s]

# %%
# !unzip -qq nba-aba-baa-stats.zip

# %%
import pandas as pd
import numpy as np

# %%
# player data containing full name/first name/ last name
players = pd.read_csv("Advanced.csv")
players.tail(10)
# Out:
#        seas_id  season  player_id          player  birth_year  pos   age  \
# 31860      195    1947        154      Tony Jaros      1920.0  F-G  26.0
# 31861      196    1947        155     Tony Kappen         NaN    G  27.0
# 31862      197    1947        155     Tony Kappen         NaN    G  27.0
# 31863      198    1947        155     Tony Kappen         NaN    G  27.0
# 31864      199    1947        156   Virgil Vaughn         NaN  F-C  28.0
# 31865      200    1947        157     Walt Miller         NaN    F  31.0
# 31866      201    1947        158   Warren Fenley         NaN    F  24.0
# 31867      202    1947        159   Wilbert Kautz         NaN  G-F  31.0
# 31868      203    1947        160  Woody Grimshaw         NaN    G  27.0
# 31869      204    1947        161     Wyndol Gray         NaN  G-F  24.0
#
#        experience   lg   tm  ...  tov_percent  usg_percent  ows  dws   ws  \
# 31860           1  BAA  CHS  ...          NaN          NaN  2.6  1.8  4.4
# ...

# %%
players = players[players.season >= 2023]
players.size
# Out:
# 45216

# %%
players.tail(10)
# Out:
#       seas_id  season  player_id              player  birth_year pos   age  \
# 1403    31126    2023       5108        Xavier Cooks         NaN  PF  27.0
# 1404    31127    2023       5020         Xavier Moon         NaN  SG  28.0
# 1405    31128    2023       5021        Xavier Sneed         NaN  SF  25.0
# 1406    31129    2023       4897  Xavier Tillman Sr.         NaN  PF  24.0
# 1407    31130    2023       4684       Yuta Watanabe         NaN  SF  28.0
# 1408    31131    2023       4580        Zach Collins         NaN   C  25.0
# 1409    31132    2023       4299         Zach LaVine         NaN  SG  27.0
# 1410    31133    2023       4898          Zeke Nnaji         NaN  PF  22.0
# 1411    31134    2023       5024     Ziaire Williams         NaN  SF  21.0
# 1412    31135    2023       4803     Zion Williamson         NaN  PF  22.0
#
#       experience   lg   tm  ...  tov_percent  usg_percent  ows  dws   ws  \
# ...

# %%
players = players[players.lg == 'NBA']
len(players.index)
# Out:
# 1413

# %%
players.drop(columns=["birth_year", "lg"], inplace=True)
players.head(10)
# Out:
#    seas_id  season  player_id             player pos   age  experience   tm  \
# 0    31136    2024       5025         A.J. Green  SG  24.0           2  MIL
# 1    31137    2024       5026        A.J. Lawson  SG  23.0           2  DAL
# 2    31138    2024       5027         AJ Griffin  SF  20.0           2  ATL
# 3    31139    2024       4219       Aaron Gordon  PF  28.0          10  DEN
# 4    31140    2024       4582      Aaron Holiday  PG  27.0           6  HOU
# 5    31141    2024       4805      Aaron Nesmith  SF  24.0           4  IND
# 6    31142    2024       4900      Aaron Wiggins  SG  25.0           3  OKC
# 7    31143    2024       5109       Adam Flagler  SG  24.0           1  OKC
# 8    31144    2024       5110       Adama Sanogo  PF  21.0           1  CHI
# 9    31145    2024       4688  Admiral Schofield  PF  26.0           4  ORL
#
#     g      mp  ...  tov_percent  usg_percent  ows  dws   ws  ws_48  obpm  \
# ...

# %%
players.columns
# Out:
# Index(['seas_id', 'season', 'player_id', 'player', 'pos', 'age', 'experience',
#        'tm', 'g', 'mp', 'per', 'ts_percent', 'x3p_ar', 'f_tr', 'orb_percent',
#        'drb_percent', 'trb_percent', 'ast_percent', 'stl_percent',
#        'blk_percent', 'tov_percent', 'usg_percent', 'ows', 'dws', 'ws',
#        'ws_48', 'obpm', 'dbpm', 'bpm', 'vorp'],
#       dtype='object')

# %%
players = players.rename(columns={'seas_id' : 'SeasonId', 'season': 'Season', 'player_id' : 'PlayerId', 'player' : 'Player',
                                  'pos' : 'Pos', 'age' : 'Age', 'experience' : 'Experience', 'tm' : 'Team', 'g' : 'GamesPlayed', 'mp' : 'MinutesPlayed'})

players.columns
# Out:
# Index(['SeasonId', 'Season', 'PlayerId', 'Player', 'Pos', 'Age', 'Experience',
#        'Team', 'GamesPlayed', 'MinutesPlayed', 'per', 'ts_percent', 'x3p_ar',
#        'f_tr', 'orb_percent', 'drb_percent', 'trb_percent', 'ast_percent',
#        'stl_percent', 'blk_percent', 'tov_percent', 'usg_percent', 'ows',
#        'dws', 'ws', 'ws_48', 'obpm', 'dbpm', 'bpm', 'vorp'],
#       dtype='object')

# %%
LeBron = players[players.Player == 'LeBron James']
LeBron.drop(columns = ['PlayerId', 'Season', 'SeasonId', 'Player', 'Pos', 'Experience', 'Age', 'Team', 'GamesPlayed', 'MinutesPlayed'], inplace=True)
LeBron.head(10)
# Out:
# <ipython-input-18-cb979d4eb518>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LeBron.drop(columns = ['PlayerId', 'Season', 'SeasonId', 'Player', 'Pos', 'Experience', 'Age', 'Team', 'GamesPlayed', 'MinutesPlayed'], inplace=True)
#        per  ts_percent  x3p_ar   f_tr  orb_percent  drb_percent  trb_percent  \
# 449   23.7       0.630   0.286  0.318          2.8         19.3         11.5
# 1149  23.9       0.583   0.309  0.268          3.7         20.8         12.5
#
#       ast_percent  stl_percent  blk_percent  tov_percent  usg_percent  ows  \
# 449          37.5          1.7          1.3         14.5         29.2  5.7
# 1149         33.5          1.2          1.4         11.6         33.3  3.2
#
#       dws   ws  ws_48  obpm  dbpm  bpm  vorp
# 449   2.8  8.5  0.164   5.5   0.9  6.5   5.4
# ...

# %%
players = players.rename(columns={'per' : 'PLayerEfficiencyRating', 'ts_percent' : 'TrueShooting%',
                                  'x3p_ar' : '3PTAttemptRate', 'f_tr' : 'FreeThrowAttemptRate', 'orb_percent' : 'OffensiveReboundPercentage',
                                  'drb_percent' : 'DefensiveReboundPercentage', 'trb_percent' : 'TrueReboundPercentage'})
players.columns
# Out:
# Index(['SeasonId', 'Season', 'PlayerId', 'Player', 'Pos', 'Age', 'Experience',
#        'Team', 'GamesPlayed', 'MinutesPlayed', 'PLayerEfficiencyRating',
#        'TrueShooting%', '3PTAttemptRate', 'FreeThrowAttemptRate',
#        'OffensiveReboundPercentage', 'DefensiveReboundPercentage',
#        'TrueReboundPercentage', 'ast_percent', 'stl_percent', 'blk_percent',
#        'tov_percent', 'usg_percent', 'ows', 'dws', 'ws', 'ws_48', 'obpm',
#        'dbpm', 'bpm', 'vorp'],
#       dtype='object')

# %%
players = players.rename(columns={'ast_percent' : 'AST%', 'stl_percent' : 'STL%',
                                  'blk_percent' : 'BLK%', 'tov_percent' : 'TOV%', 'usg_percent' : 'USG%',
                                  'ows' : 'OffWinShare', 'dws' : 'DefWinShare', 'ws' : 'WinShare', 'vorp' : 'ValueOverReplacement'})
players.columns
# Out:
# Index(['SeasonId', 'Season', 'PlayerId', 'Player', 'Pos', 'Age', 'Experience',
#        'Team', 'GamesPlayed', 'MinutesPlayed', 'PLayerEfficiencyRating',
#        'TrueShooting%', '3PTAttemptRate', 'FreeThrowAttemptRate',
#        'OffensiveReboundPercentage', 'DefensiveReboundPercentage',
#        'TrueReboundPercentage', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OffWinShare', 'DefWinShare', 'WinShare', 'ws_48', 'obpm', 'dbpm',
#        'bpm', 'ValueOverReplacement'],
#       dtype='object')

# %%
players.drop(columns=["obpm", "dbpm", "bpm"], inplace=True)

# %% [markdown]
# ## This is the end of advanced stats and the beginning of the next set of stats as selected from Player Totals
#
# Below is the dataframe containing data concerning the individual prowess of players during the season -- cleaned up to contain only the vital deatils

# %%
# player data containing full name/first name/ last name
player_stats = pd.read_csv("Player Totals.csv")
player_stats.tail(10)
# Out:
#        seas_id  season  player_id          player  birth_year  pos   age  \
# 31860      195    1947        154      Tony Jaros      1920.0  F-G  26.0
# 31861      196    1947        155     Tony Kappen         NaN    G  27.0
# 31862      197    1947        155     Tony Kappen         NaN    G  27.0
# 31863      198    1947        155     Tony Kappen         NaN    G  27.0
# 31864      199    1947        156   Virgil Vaughn         NaN  F-C  28.0
# 31865      200    1947        157     Walt Miller         NaN    F  31.0
# 31866      201    1947        158   Warren Fenley         NaN    F  24.0
# 31867      202    1947        159   Wilbert Kautz         NaN  G-F  31.0
# 31868      203    1947        160  Woody Grimshaw         NaN    G  27.0
# 31869      204    1947        161     Wyndol Gray         NaN  G-F  24.0
#
#        experience   lg   tm  ...  ft_percent  orb  drb  trb  ast  stl  blk  \
# 31860           1  BAA  CHS  ...       0.707  NaN  NaN  NaN   28  NaN  NaN
# ...

# %%
player_stats = player_stats[player_stats.season >= 2023]
player_stats.head(10)
# Out:
#    seas_id  season  player_id             player  birth_year pos   age  \
# 0    31136    2024       5025         A.J. Green         NaN  SG  24.0
# 1    31137    2024       5026        A.J. Lawson         NaN  SG  23.0
# 2    31138    2024       5027         AJ Griffin         NaN  SF  20.0
# 3    31139    2024       4219       Aaron Gordon         NaN  PF  28.0
# 4    31140    2024       4582      Aaron Holiday         NaN  PG  27.0
# 5    31141    2024       4805      Aaron Nesmith         NaN  SF  24.0
# 6    31142    2024       4900      Aaron Wiggins         NaN  SG  25.0
# 7    31143    2024       5109       Adam Flagler         NaN  SG  24.0
# 8    31144    2024       5110       Adama Sanogo         NaN  PF  21.0
# 9    31145    2024       4688  Admiral Schofield         NaN  PF  26.0
#
#    experience   lg   tm  ...  ft_percent    orb    drb    trb  ast   stl  \
# 0           2  NBA  MIL  ...       0.895    9.0   55.0   64.0   30   9.0
# ...

# %%
player_stats.columns
# Out:
# Index(['seas_id', 'season', 'player_id', 'player', 'birth_year', 'pos', 'age',
#        'experience', 'lg', 'tm', 'g', 'gs', 'mp', 'fg', 'fga', 'fg_percent',
#        'x3p', 'x3pa', 'x3p_percent', 'x2p', 'x2pa', 'x2p_percent',
#        'e_fg_percent', 'ft', 'fta', 'ft_percent', 'orb', 'drb', 'trb', 'ast',
#        'stl', 'blk', 'tov', 'pf', 'pts'],
#       dtype='object')

# %%
player_stats.drop(columns=['birth_year', 'lg'], inplace=True)
print(len(player_stats.index))
# Out:
# 1413

# %%
player_stats.head(10)
# Out:
#    seas_id  season  player_id             player pos   age  experience   tm  \
# 0    31136    2024       5025         A.J. Green  SG  24.0           2  MIL
# 1    31137    2024       5026        A.J. Lawson  SG  23.0           2  DAL
# 2    31138    2024       5027         AJ Griffin  SF  20.0           2  ATL
# 3    31139    2024       4219       Aaron Gordon  PF  28.0          10  DEN
# 4    31140    2024       4582      Aaron Holiday  PG  27.0           6  HOU
# 5    31141    2024       4805      Aaron Nesmith  SF  24.0           4  IND
# 6    31142    2024       4900      Aaron Wiggins  SG  25.0           3  OKC
# 7    31143    2024       5109       Adam Flagler  SG  24.0           1  OKC
# 8    31144    2024       5110       Adama Sanogo  PF  21.0           1  CHI
# 9    31145    2024       4688  Admiral Schofield  PF  26.0           4  ORL
#
#     g    gs  ...  ft_percent    orb    drb    trb  ast   stl   blk    tov  \
# ...

# %%
player_stats.drop(columns=['seas_id', 'gs'], inplace=True)

# %%
player_stats.columns
# Out:
# Index(['season', 'player_id', 'player', 'pos', 'age', 'experience', 'tm', 'g',
#        'mp', 'fg', 'fga', 'fg_percent', 'x3p', 'x3pa', 'x3p_percent', 'x2p',
#        'x2pa', 'x2p_percent', 'e_fg_percent', 'ft', 'fta', 'ft_percent', 'orb',
#        'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts'],
#       dtype='object')

# %%
player_stats['fg_percent']
# Out:
# 0       0.423
# 1       0.446
# 2       0.290
# 3       0.556
# 4       0.446
#         ...
# 1408    0.518
# 1409    0.485
# 1410    0.561
# 1411    0.429
# 1412    0.608
# Name: fg_percent, Length: 1413, dtype: float64

# %%
player_stats = player_stats.rename(columns={'season' : 'Season', 'player_id' : 'PlayerId', 'player' : 'Player', 'pos' : 'Position',
                                            'age' : 'Age', 'experience' : 'Experience', 'tm' : 'Team', 'g' : 'GamesPlayed', 'mp' : 'MinutesPlayed',
                                            'fg' : 'FGM', 'fga' : 'FGA', 'fg_percent' : 'FG%', 'x3p' : '3PM', 'x3pa' : '3PA',
                                            'x3p_percent' : '3P%', 'x2p' : '2PM', 'x2pa' : '2PA', 'x2p_percent' : '2P%', 'ft' : 'FT',
                                            'fta' : 'FTA', 'ft_percent' : 'FT%', 'orb' : 'OffReb', 'drb' : 'DefReb', 'trb' : 'TrueReb',
                                            'ast' : 'AST', 'stl' : 'STL', 'blk' : 'BLK', 'tov' : 'TOV', 'pf' : 'PersonalFoul', 'pts' : 'PTS'})
player_stats.columns
# Out:
# Index(['Season', 'PlayerId', 'Player', 'Position', 'Age', 'Experience', 'Team',
#        'GamesPlayed', 'MinutesPlayed', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#        '3P%', '2PM', '2PA', '2P%', 'e_fg_percent', 'FT', 'FTA', 'FT%',
#        'OffReb', 'DefReb', 'TrueReb', 'AST', 'STL', 'BLK', 'TOV',
#        'PersonalFoul', 'PTS'],
#       dtype='object')

# %%
player_stats.drop(columns=['e_fg_percent'], inplace=True)
player_stats.columns
# Out:
# Index(['Season', 'PlayerId', 'Player', 'Position', 'Age', 'Experience', 'Team',
#        'GamesPlayed', 'MinutesPlayed', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#        '3P%', '2PM', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'OffReb', 'DefReb',
#        'TrueReb', 'AST', 'STL', 'BLK', 'TOV', 'PersonalFoul', 'PTS'],
#       dtype='object')

# %%
lakers = player_stats[player_stats.Team == "LAL"]
lakers
# Out:
#       Season  PlayerId                 Player Position   Age  Experience Team  \
# 19      2024      5111             Alex Fudge       SF  20.0           1  LAL
# 34      2024      4066          Anthony Davis        C  30.0          12  LAL
# 40      2024      4906          Austin Reaves       SG  25.0           3  LAL
# 82      2024      4697            Cam Reddish       SF  24.0           5  LAL
# 103     2024      4313         Christian Wood       PF  28.0           8  LAL
# 112     2024      5128        Colin Castleton        C  23.0           1  LAL
# 118     2024      4317       D'Angelo Russell       PG  27.0           9  LAL
# 119     2024      5131            D'Moi Hodge       SG  25.0           1  LAL
# 201     2024      4829          Dylan Windler       SF  27.0           4  LAL
# 223     2024      4717           Gabe Vincent       PG  27.0           5  LAL
# 246     2024      4622            Harry Giles        C  25.0           4  LAL
# ...

# %%
file_name = 'LakerStats.xlsx'
lakers.to_excel(file_name)
print("Successfully converted")
# Out:
# Successfully converted

# %%
file_name = 'PlayerStats.xlsx'
player_stats.to_excel(file_name)
print("Successfully converted the DF to an excel sheet")
# Out:
# Successfully converted the DF to an excel sheet

# %% [markdown]
# ## Next Section -- Examining Team Stats
# Here are the statistics regarding individual team performances

# %%
# player data containing full name/first name/ last name
team_stats = pd.read_csv("Team Summaries.csv")
team_stats.head(10)
# Out:
#    season   lg                   team abbreviation  playoffs   age     w  \
# 0    2024  NBA          Atlanta Hawks          ATL     False  26.2  36.0
# 1    2024  NBA         Boston Celtics          BOS      True  28.2  64.0
# 2    2024  NBA          Brooklyn Nets          BRK     False  26.1  32.0
# 3    2024  NBA          Chicago Bulls          CHI     False  28.1  39.0
# 4    2024  NBA      Charlotte Hornets          CHO     False  25.1  21.0
# 5    2024  NBA    Cleveland Cavaliers          CLE     False  26.2  48.0
# 6    2024  NBA       Dallas Mavericks          DAL      True  26.5  50.0
# 7    2024  NBA         Denver Nuggets          DEN      True  27.1  57.0
# 8    2024  NBA        Detroit Pistons          DET     False  23.8  14.0
# 9    2024  NBA  Golden State Warriors          GSW     False  28.4  46.0
#
#       l    pw    pl  ...  tov_percent  orb_percent  ft_fga  opp_e_fg_percent  \
# 0  46.0  36.0  46.0  ...         11.6         27.1   0.200             0.572
# ...

# %%
team_stats = team_stats[team_stats.season >= 2023]
team_stats
# Out:
#     season   lg                team abbreviation  playoffs   age     w     l  \
# 0     2024  NBA       Atlanta Hawks          ATL     False  26.2  36.0  46.0
# 1     2024  NBA      Boston Celtics          BOS      True  28.2  64.0  18.0
# 2     2024  NBA       Brooklyn Nets          BRK     False  26.1  32.0  50.0
# 3     2024  NBA       Chicago Bulls          CHI     False  28.1  39.0  43.0
# 4     2024  NBA   Charlotte Hornets          CHO     False  25.1  21.0  61.0
# ..     ...  ...                 ...          ...       ...   ...   ...   ...
# 57    2023  NBA   San Antonio Spurs          SAS     False  23.9  22.0  60.0
# 58    2023  NBA     Toronto Raptors          TOR     False  25.8  41.0  41.0
# 59    2023  NBA           Utah Jazz          UTA     False  26.5  37.0  45.0
# 60    2023  NBA  Washington Wizards          WAS     False  26.2  35.0  47.0
# 61    2023  NBA      League Average          NaN     False  26.3   NaN   NaN
#
# ...

# %%
team_stats = team_stats[team_stats.team != 'League Average']
team_stats.head(5)
# Out:
#    season   lg               team abbreviation  playoffs   age     w     l  \
# 0    2024  NBA      Atlanta Hawks          ATL     False  26.2  36.0  46.0
# 1    2024  NBA     Boston Celtics          BOS      True  28.2  64.0  18.0
# 2    2024  NBA      Brooklyn Nets          BRK     False  26.1  32.0  50.0
# 3    2024  NBA      Chicago Bulls          CHI     False  28.1  39.0  43.0
# 4    2024  NBA  Charlotte Hornets          CHO     False  25.1  21.0  61.0
#
#      pw    pl  ...  tov_percent  orb_percent  ft_fga  opp_e_fg_percent  \
# 0  36.0  46.0  ...         11.6         27.1   0.200             0.572
# 1  66.0  16.0  ...         10.8         24.9   0.180             0.523
# 2  34.0  48.0  ...         11.8         25.2   0.177             0.543
# 3  37.0  45.0  ...         11.0         25.1   0.187             0.556
# 4  18.0  64.0  ...         12.6         21.1   0.167             0.572
#
#    opp_tov_percent  opp_drb_percent  opp_ft_fga             arena    attend  \
# ...

# %%
team_stats.columns
# Out:
# Index(['season', 'lg', 'team', 'abbreviation', 'playoffs', 'age', 'w', 'l',
#        'pw', 'pl', 'mov', 'sos', 'srs', 'o_rtg', 'd_rtg', 'n_rtg', 'pace',
#        'f_tr', 'x3p_ar', 'ts_percent', 'e_fg_percent', 'tov_percent',
#        'orb_percent', 'ft_fga', 'opp_e_fg_percent', 'opp_tov_percent',
#        'opp_drb_percent', 'opp_ft_fga', 'arena', 'attend', 'attend_g'],
#       dtype='object')

# %%
team_stats.drop(columns=["lg", "age", "attend", "attend_g"], inplace=True)
team_stats.head(10)
# Out:
# <ipython-input-39-e16144cb6312>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_stats.drop(columns=["lg", "age", "attend", "attend_g"], inplace=True)
#    season                   team abbreviation  playoffs     w     l    pw  \
# 0    2024          Atlanta Hawks          ATL     False  36.0  46.0  36.0
# 1    2024         Boston Celtics          BOS      True  64.0  18.0  66.0
# 2    2024          Brooklyn Nets          BRK     False  32.0  50.0  34.0
# 3    2024          Chicago Bulls          CHI     False  39.0  43.0  37.0
# 4    2024      Charlotte Hornets          CHO     False  21.0  61.0  18.0
# 5    2024    Cleveland Cavaliers          CLE     False  48.0  34.0  47.0
# 6    2024       Dallas Mavericks          DAL      True  50.0  32.0  46.0
# ...

# %%
team_stats.columns
# Out:
# Index(['season', 'team', 'abbreviation', 'playoffs', 'w', 'l', 'pw', 'pl',
#        'mov', 'sos', 'srs', 'o_rtg', 'd_rtg', 'n_rtg', 'pace', 'f_tr',
#        'x3p_ar', 'ts_percent', 'e_fg_percent', 'tov_percent', 'orb_percent',
#        'ft_fga', 'opp_e_fg_percent', 'opp_tov_percent', 'opp_drb_percent',
#        'opp_ft_fga', 'arena'],
#       dtype='object')

# %%
team_stats.drop(columns=["pw", "pl", "mov", "sos", "srs", "pace"], inplace=True)
team_stats.head(10)
# Out:
# <ipython-input-41-1f5bdb4273c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_stats.drop(columns=["pw", "pl", "mov", "sos", "srs", "pace"], inplace=True)
#    season                   team abbreviation  playoffs     w     l  o_rtg  \
# 0    2024          Atlanta Hawks          ATL     False  36.0  46.0  117.2
# 1    2024         Boston Celtics          BOS      True  64.0  18.0  123.2
# 2    2024          Brooklyn Nets          BRK     False  32.0  50.0  113.2
# 3    2024          Chicago Bulls          CHI     False  39.0  43.0  114.9
# 4    2024      Charlotte Hornets          CHO     False  21.0  61.0  109.3
# 5    2024    Cleveland Cavaliers          CLE     False  48.0  34.0  115.2
# 6    2024       Dallas Mavericks          DAL      True  50.0  32.0  117.6
# ...

# %%
team_stats.columns
# Out:
# Index(['season', 'team', 'abbreviation', 'playoffs', 'w', 'l', 'o_rtg',
#        'd_rtg', 'n_rtg', 'f_tr', 'x3p_ar', 'ts_percent', 'e_fg_percent',
#        'tov_percent', 'orb_percent', 'ft_fga', 'opp_e_fg_percent',
#        'opp_tov_percent', 'opp_drb_percent', 'opp_ft_fga', 'arena'],
#       dtype='object')

# %%
team_stats.drop(columns=["n_rtg", "e_fg_percent"], inplace=True)
# Out:
# <ipython-input-43-1083a04bb7de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_stats.drop(columns=["n_rtg", "e_fg_percent"], inplace=True)

# %%
team_stats.columns
# Out:
# Index(['season', 'team', 'abbreviation', 'playoffs', 'w', 'l', 'o_rtg',
#        'd_rtg', 'f_tr', 'x3p_ar', 'ts_percent', 'tov_percent', 'orb_percent',
#        'ft_fga', 'opp_e_fg_percent', 'opp_tov_percent', 'opp_drb_percent',
#        'opp_ft_fga', 'arena'],
#       dtype='object')

# %%
team_stats['x3p_ar'].head(10)
# Out:
# 0    0.408
# 1    0.471
# 2    0.412
# 3    0.358
# 4    0.391
# 5    0.422
# 6    0.441
# 7    0.352
# 8    0.360
# 9    0.425
# Name: x3p_ar, dtype: float64

# %%
team_stats = team_stats.rename(columns={'season' : 'Season', 'team' : 'Team',
                                  'abbreviation' : 'Abbrviation', 'w' : 'W', 'l' : 'L',
                                  'o_rtg' : 'OffRating', 'd_rtg' : 'DefRating', 'f_tr' : 'FreeThrows', 'x3p_ar' : '3PAttemptRate',
                                  'ts_percent' : 'TrueShooting%', 'tov_percent' : 'TurnOver%', 'orb_percent' : 'OffReb%',
                                  'ft_fga' : 'FreeThrowFGA', 'opp_e_fg_percent' : 'OppFG%', 'opp_tov_percent' : 'OppTOV%',
                                  'opp_drb_percent' : 'OppDefReb%', 'opp_ft_fga' : 'OppFtFGA'})
team_stats.drop(columns=['arena'], inplace=True)
team_stats.head(10)
# Out:
#    Season                   Team Abbrviation  playoffs     W     L  OffRating  \
# 0    2024          Atlanta Hawks         ATL     False  36.0  46.0      117.2
# 1    2024         Boston Celtics         BOS      True  64.0  18.0      123.2
# 2    2024          Brooklyn Nets         BRK     False  32.0  50.0      113.2
# 3    2024          Chicago Bulls         CHI     False  39.0  43.0      114.9
# 4    2024      Charlotte Hornets         CHO     False  21.0  61.0      109.3
# 5    2024    Cleveland Cavaliers         CLE     False  48.0  34.0      115.2
# 6    2024       Dallas Mavericks         DAL      True  50.0  32.0      117.6
# 7    2024         Denver Nuggets         DEN      True  57.0  25.0      118.5
# 8    2024        Detroit Pistons         DET     False  14.0  68.0      109.7
# 9    2024  Golden State Warriors         GSW     False  46.0  36.0      117.8
#
#    DefRating  FreeThrows  3PAttemptRate  TrueShooting%  TurnOver%  OffReb%  \
# ...

# %%
team_summary = pd.read_csv('Team Totals.csv')
team_summary.head(3)
# Out:
#    season   lg            team abbreviation  playoffs     g       mp      fg  \
# 0    2024  NBA   Atlanta Hawks          ATL     False  82.0  19855.0  3529.0
# 1    2024  NBA  Boston Celtics          BOS      True  82.0  19830.0  3601.0
# 2    2024  NBA   Brooklyn Nets          BRK     False  82.0  19805.0  3334.0
#
#       fga  fg_percent  ...  ft_percent     orb     drb     trb     ast    stl  \
# 0  7584.0       0.465  ...       0.797  1024.0  2639.0  3663.0  2180.0  615.0
# 1  7396.0       0.487  ...       0.807   876.0  2923.0  3799.0  2207.0  557.0
# 2  7307.0       0.456  ...       0.756   938.0  2675.0  3613.0  2102.0  556.0
#
#      blk     tov      pf     pts
# 0  369.0  1110.0  1522.0  9703.0
# 1  538.0   979.0  1326.0  9887.0
# 2  424.0  1076.0  1516.0  9050.0
#
# [3 rows x 28 columns]

# %%
team_summary.columns
# Out:
# Index(['season', 'lg', 'team', 'abbreviation', 'playoffs', 'g', 'mp', 'fg',
#        'fga', 'fg_percent', 'x3p', 'x3pa', 'x3p_percent', 'x2p', 'x2pa',
#        'x2p_percent', 'ft', 'fta', 'ft_percent', 'orb', 'drb', 'trb', 'ast',
#        'stl', 'blk', 'tov', 'pf', 'pts'],
#       dtype='object')

# %%
team_summary.drop(columns=['lg', 'g', 'mp'], inplace=True)
team_summary.tail(3)
# Out:
#       season                 team abbreviation  playoffs      fg     fga  \
# 1842    1947      Toronto Huskies          TRH     False  1515.0  5672.0
# 1843    1947  Washington Capitols          WSC      True  1723.0  5794.0
# 1844    1947       League Average          NaN     False  1561.0  5592.0
#
#       fg_percent  x3p  x3pa  x3p_percent  ...  ft_percent  orb  drb  trb  \
# 1842       0.267  NaN   NaN          NaN  ...       0.622  NaN  NaN  NaN
# 1843       0.297  NaN   NaN          NaN  ...       0.706  NaN  NaN  NaN
# 1844       0.279  NaN   NaN          NaN  ...       0.641  NaN  NaN  NaN
#
#         ast  stl  blk  tov      pf     pts
# 1842  463.0  NaN  NaN  NaN  1271.0  3996.0
# 1843  378.0  NaN  NaN  NaN  1144.0  4428.0
# 1844  415.0  NaN  NaN  NaN  1254.0  4078.0
#
# [3 rows x 25 columns]

# %%
team_summary = team_summary.rename(columns={'season' : 'Season', 'team' : 'Team', 'abbreviation' : 'Abbreviation', 'playoffs' : 'Playoffs',
                                            'fg' : 'FGM', 'fga' : 'FGA', 'fg_percent' : 'FG%', 'x3p' : '3PM', 'x3pa' : '3PA',
                                            'x3p_percent' : '3P%', 'x2p' : '2PM', 'x2pa' : '2PA', 'x2p_percent' : '2P%', 'ft' : 'FT',
                                            'fta' : 'FTA', 'ft_percent' : 'FT%', 'orb' : 'OffReb', 'drb' : 'DefReb', 'trb' : 'TrueReb',
                                            'ast' : 'AST', 'stl' : 'STL', 'blk' : 'BLK', 'tov' : 'TOV', 'pf' : 'PersonalFoul', 'pts' : 'PTS'})
team_summary.columns
# Out:
# Index(['Season', 'Team', 'Abbreviation', 'Playoffs', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', '2PM', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'OffReb',
#        'DefReb', 'TrueReb', 'AST', 'STL', 'BLK', 'TOV', 'PersonalFoul', 'PTS'],
#       dtype='object')

# %%
team_summary = team_summary[team_summary.Season >= 2023]
team_summary = team_summary[team_summary.Team != 'League Average']
len(team_summary)
# Out:
# 60

# %%
team_stats = team_stats.rename(columns={'Team' : 'team'})
team_summary_final = pd.concat([team_summary, team_stats], axis=1)
team_summary_final.columns
# Out:
# Index(['Season', 'Team', 'Abbreviation', 'Playoffs', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', '2PM', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'OffReb',
#        'DefReb', 'TrueReb', 'AST', 'STL', 'BLK', 'TOV', 'PersonalFoul', 'PTS',
#        'Season', 'team', 'Abbrviation', 'playoffs', 'W', 'L', 'OffRating',
#        'DefRating', 'FreeThrows', '3PAttemptRate', 'TrueShooting%',
#        'TurnOver%', 'OffReb%', 'FreeThrowFGA', 'OppFG%', 'OppTOV%',
#        'OppDefReb%', 'OppFtFGA'],
#       dtype='object')

# %%
team_summary_final.drop(columns=['team', 'Abbrviation', 'playoffs'], inplace=True)
team_summary_final.columns
# Out:
# Index(['Season', 'Team', 'Abbreviation', 'Playoffs', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', '2PM', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'OffReb',
#        'DefReb', 'TrueReb', 'AST', 'STL', 'BLK', 'TOV', 'PersonalFoul', 'PTS',
#        'Season', 'W', 'L', 'OffRating', 'DefRating', 'FreeThrows',
#        '3PAttemptRate', 'TrueShooting%', 'TurnOver%', 'OffReb%',
#        'FreeThrowFGA', 'OppFG%', 'OppTOV%', 'OppDefReb%', 'OppFtFGA'],
#       dtype='object')

# %%
file_name = 'TeamStats.xlsx'
team_summary_final.to_excel(file_name)
print("Success")
# Out:
# Success

# %%
team_summary.head(3)
# Out:
#    Season            Team Abbreviation  Playoffs     FGM     FGA    FG%  \
# 0    2024   Atlanta Hawks          ATL     False  3529.0  7584.0  0.465
# 1    2024  Boston Celtics          BOS      True  3601.0  7396.0  0.487
# 2    2024   Brooklyn Nets          BRK     False  3334.0  7307.0  0.456
#
#       3PM     3PA    3P%  ...    FT%  OffReb  DefReb  TrueReb     AST    STL  \
# 0  1125.0  3092.0  0.364  ...  0.797  1024.0  2639.0   3663.0  2180.0  615.0
# 1  1351.0  3482.0  0.388  ...  0.807   876.0  2923.0   3799.0  2207.0  557.0
# 2  1089.0  3010.0  0.362  ...  0.756   938.0  2675.0   3613.0  2102.0  556.0
#
#      BLK     TOV  PersonalFoul     PTS
# 0  369.0  1110.0        1522.0  9703.0
# 1  538.0   979.0        1326.0  9887.0
# 2  424.0  1076.0        1516.0  9050.0
#
# [3 rows x 25 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# A list for the bottom might be better
team_list = ["ATL", "BOS", "LAL "]
spec_stats = team_summary[(team_summary["Abbreviation"] == "ATL") | (team_summary["Abbreviation"] == "BOS") | (team_summary["Abbreviation"] == "LAL")]
spec_stats
# Out:
#     Season                Team Abbreviation  Playoffs     FGM     FGA    FG%  \
# 0     2024       Atlanta Hawks          ATL     False  3529.0  7584.0  0.465
# 1     2024      Boston Celtics          BOS      True  3601.0  7396.0  0.487
# 13    2024  Los Angeles Lakers          LAL     False  3580.0  7177.0  0.499
# 31    2023       Atlanta Hawks          ATL     False  3658.0  7574.0  0.483
# 32    2023      Boston Celtics          BOS     False  3460.0  7278.0  0.475
# 44    2023  Los Angeles Lakers          LAL     False  3516.0  7298.0  0.482
#
#        3PM     3PA    3P%  ...    FT%  OffReb  DefReb  TrueReb     AST    STL  \
# 0   1125.0  3092.0  0.364  ...  0.797  1024.0  2639.0   3663.0  2180.0  615.0
# 1   1351.0  3482.0  0.388  ...  0.807   876.0  2923.0   3799.0  2207.0  557.0
# 13   969.0  2572.0  0.377  ...  0.782   676.0  2859.0   3535.0  2340.0  605.0
# 31   882.0  2505.0  0.352  ...  0.818   920.0  2719.0   3639.0  2049.0  580.0
# ...
